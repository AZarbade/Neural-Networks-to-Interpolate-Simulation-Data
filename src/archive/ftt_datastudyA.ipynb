# %%
import sklearn.preprocessing
import torch
import delu
import delu.data
import math

# settings
device = torch.device('cuda')
delu.improve_reproducibility(base_seed=1024)

# wandb config
config = {
    "learning_rate": 0.0003,
    "epochs": 1000,
    "batch_size": 32,
    "dropout": 0.2,
    "train_split": 0.8,
    "weight_decay": 0.0,
    "patience": 100
}

# %%
import pandas as pd
import sklearn
import sklearn.model_selection
import sklearn.metrics
import torch
from torch.utils.data import Dataset

import delu
delu.improve_reproducibility(base_seed=1024)

class drdo_data(Dataset):
    def __init__(self, dataset, dep_variable, train_split, device,
                 all_pp: bool=False, no_pp: bool=False, target_pp: bool=False, feature_pp: bool=False,
                 type: int=1) -> None:
        self.train_split = train_split
        self.device = device
        self.dataset = dataset
        self.dep_variable = dep_variable
        self.df = pd.read_csv(dataset)
        self.X = {}
        self.y = {}

        y_all = self.df[dep_variable].astype('float32').to_numpy()
        X_all = self.df.drop(dep_variable, axis=1).astype('float32').to_numpy()

        if type == 1:
            print('type I processing')
            self.X['train'], self.X['test'], self.y['train'], self.y['test'] = sklearn.model_selection.train_test_split(
                X_all, y_all, train_size=train_split, random_state=1024)

            self.X['train'], self.X['val'], self.y['train'], self.y['val'] = sklearn.model_selection.train_test_split(
                self.X['train'], self.y['train'], train_size=train_split, random_state=1024)
        if type == 2:
            print('type II processing')
            self.X['train'] = X_all
            self.y['train'] = y_all
        
        if all_pp == True:
            print('processing: [features, targets]')
            preprocess = sklearn.preprocessing.QuantileTransformer()
            preprocess.fit(self.X['train'])
            self.X = {k: torch.tensor(preprocess.transform(v), device=device) for k, v in self.X.items()}
            self.y = {k: torch.tensor(v, device=device) for k, v in self.y.items()}
            self.y_mean = self.y['train'].mean().item()
            self.y_std = self.y['train'].std().item()
            self.y = {k: (v - self.y_mean) / self.y_std for k, v in self.y.items()}
        else:
            pass

        if no_pp == True:
            print('processing: []')
            self.X = {k: torch.tensor(v, device=device) for k, v in self.X.items()}
            self.y = {k: torch.tensor(v, device=device) for k, v in self.y.items()}
        else:
            pass

        if target_pp == True:
            print('processing: [targets]')
            self.X = {k: torch.tensor(v, device=device) for k, v in self.X.items()}
            self.y = {k: torch.tensor(v, device=device) for k, v in self.y.items()}
            self.y_mean = self.y['train'].mean().item()
            self.y_std = self.y['train'].std().item()
            self.y = {k: (v - self.y_mean) / self.y_std for k, v in self.y.items()}
        else:
            pass

        if feature_pp == True:
            print('processing: [features]')
            preprocess = sklearn.preprocessing.QuantileTransformer()
            preprocess.fit(self.X['train'])
            self.X = {k: torch.tensor(preprocess.transform(v), device=device) for k, v in self.X.items()}
            self.y = {k: torch.tensor(v, device=device) for k, v in self.y.items()}
        else:
            pass

    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, index):
        return self.X['train'][index], self.y['train'][index]

# %%
df = pd.read_csv('../../data/SIDI_Full.csv')
df.head(3)
# Out:
#    LD  Velocity (km/s)  a (degrees)  $ (degrees)       DI
# 0   1             0.25           90           75  0.00007
# 1   1             0.25           90           60  0.00580
# 2   1             0.25           90           45  0.01259

# %%
inp_2222 = drdo_data(
    dataset='../../data/input_2-2-2-2.csv',
    dep_variable='DI',
    train_split=0.8,
    device=device,
    feature_pp=True,
    type=2
)

filler_2222 = drdo_data(
    dataset='../../data/filler_2-2-2-2.csv',
    dep_variable='DI',
    train_split=0.8,
    device=device,
    feature_pp=True,
    type=2
)

inp_3334 = drdo_data(
    dataset='../../data/input_3-3-3-4.csv',
    dep_variable='DI',
    train_split=0.8,
    device=device,
    feature_pp=True,
    type=2
)

filler_3334 = drdo_data(
    dataset='../../data/filler_3-3-3-4.csv',
    dep_variable='DI',
    train_split=0.8,
    device=device,
    feature_pp=True,
    type=2
)

full_data = drdo_data(
    dataset='../../data/SIDI_Full.csv',
    dep_variable='DI',
    train_split=0.8,
    device=device,
    feature_pp=True,
    type=1
)
# Out:
# type II processing
# processing: [features]
# /home/hackerman/miniconda3/envs/hvis/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (22). n_quantiles is set to n_samples.
#   warnings.warn(
# type II processing
# processing: [features]
# type II processing
# processing: [features]
# type II processing
# processing: [features]
# type I processing
# processing: [features]
# /home/hackerman/miniconda3/envs/hvis/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (198). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/hackerman/miniconda3/envs/hvis/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (177). n_quantiles is set to n_samples.
#   warnings.warn(
# /home/hackerman/miniconda3/envs/hvis/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (1000) is greater than the total number of samples (191). n_quantiles is set to n_samples.
#   warnings.warn(

# %%
losses = {'inp_2222': [], 'inp_3334': [], 'full_data': []}

# %%
import math
import rtdl

data = full_data
eval_data = full_data
model = rtdl.FTTransformer.make_default(
    n_num_features=data.X['train'].shape[1],
    cat_cardinalities=None,
    last_layer_query_idx=[-1],  # it makes the model faster and does NOT affect its output
    d_out=1,
)

model.to(device)
optimizer = (
    torch.optim.AdamW(model.parameters(),
    lr=config['learning_rate'],
    weight_decay=config['weight_decay'])
)
loss_fn = torch.nn.MSELoss()

@torch.no_grad()
def evaluate(part):
    model.eval()
    pred = model(eval_data.X[part], x_cat=None).squeeze(1)
    target = eval_data.y[part]
    score = loss_fn(pred, target)
    return score

# Create a dataloader for batches of indices
batch_size = config['batch_size']
train_loader = delu.data.make_index_dataloader(len(data.X['train']), config['batch_size'])

# Create a progress tracker for early stopping
progress = delu.ProgressTracker(config['patience'])
print(f'Test score before training: {evaluate("train"):.4f}')

n_epochs = config['epochs']
for epoch in range(n_epochs):
    for iteration, batch_idx in enumerate(train_loader):
        model.train()
        optimizer.zero_grad()
        x_batch = data.X['train'][batch_idx]
        y_batch = data.y['train'][batch_idx]
        loss = loss_fn(model(x_batch, x_cat=None).squeeze(1), y_batch)
        loss.backward()
        optimizer.step()

    # val_score = evaluate('val')
    test_score = evaluate('test')

    # valid_rmse = math.sqrt(val_score.cpu().numpy())
    test_rmse = math.sqrt(test_score.cpu().numpy())

    losses['full_data'].append(test_rmse)

    print(f'Epoch {epoch:03d} | Test score: {test_score:.4f}', end='')
    progress.update((-1) * test_score)
    if progress.success:
        print(' <<< BEST VALIDATION EPOCH', end='')
    print()
    if progress.fail:
        break
# Out:
# Test score before training: 0.4440
# Epoch 000 | Test score: 0.0192 <<< BEST VALIDATION EPOCH
# Epoch 001 | Test score: 0.0059 <<< BEST VALIDATION EPOCH
# Epoch 002 | Test score: 0.0030 <<< BEST VALIDATION EPOCH
# Epoch 003 | Test score: 0.0030 <<< BEST VALIDATION EPOCH
# Epoch 004 | Test score: 0.0022 <<< BEST VALIDATION EPOCH
# Epoch 005 | Test score: 0.0029
# Epoch 006 | Test score: 0.0017 <<< BEST VALIDATION EPOCH
# Epoch 007 | Test score: 0.0030
# Epoch 008 | Test score: 0.0016 <<< BEST VALIDATION EPOCH
# Epoch 009 | Test score: 0.0042
# Epoch 010 | Test score: 0.0024
# Epoch 011 | Test score: 0.0019
# Epoch 012 | Test score: 0.0035
# Epoch 013 | Test score: 0.0012 <<< BEST VALIDATION EPOCH
# Epoch 014 | Test score: 0.0016
# Epoch 015 | Test score: 0.0016
# Epoch 016 | Test score: 0.0015
# Epoch 017 | Test score: 0.0013
# Epoch 018 | Test score: 0.0018
# Epoch 019 | Test score: 0.0011 <<< BEST VALIDATION EPOCH
# Epoch 020 | Test score: 0.0024
# Epoch 021 | Test score: 0.0010 <<< BEST VALIDATION EPOCH
# Epoch 022 | Test score: 0.0010
# Epoch 023 | Test score: 0.0016
# Epoch 024 | Test score: 0.0012
# Epoch 025 | Test score: 0.0015
# Epoch 026 | Test score: 0.0010
# Epoch 027 | Test score: 0.0011
# Epoch 028 | Test score: 0.0011
# Epoch 029 | Test score: 0.0009 <<< BEST VALIDATION EPOCH
# Epoch 030 | Test score: 0.0011
# Epoch 031 | Test score: 0.0012
# Epoch 032 | Test score: 0.0009
# Epoch 033 | Test score: 0.0010
# Epoch 034 | Test score: 0.0009 <<< BEST VALIDATION EPOCH
# Epoch 035 | Test score: 0.0010
# Epoch 036 | Test score: 0.0009
# Epoch 037 | Test score: 0.0006 <<< BEST VALIDATION EPOCH
# Epoch 038 | Test score: 0.0008
# Epoch 039 | Test score: 0.0012
# Epoch 040 | Test score: 0.0006
# Epoch 041 | Test score: 0.0007
# Epoch 042 | Test score: 0.0005 <<< BEST VALIDATION EPOCH
# Epoch 043 | Test score: 0.0009
# Epoch 044 | Test score: 0.0008
# Epoch 045 | Test score: 0.0006
# Epoch 046 | Test score: 0.0007
# Epoch 047 | Test score: 0.0006
# Epoch 048 | Test score: 0.0007
# Epoch 049 | Test score: 0.0009
# Epoch 050 | Test score: 0.0005 <<< BEST VALIDATION EPOCH
# Epoch 051 | Test score: 0.0006
# Epoch 052 | Test score: 0.0004 <<< BEST VALIDATION EPOCH
# Epoch 053 | Test score: 0.0011
# Epoch 054 | Test score: 0.0004 <<< BEST VALIDATION EPOCH
# Epoch 055 | Test score: 0.0004 <<< BEST VALIDATION EPOCH
# Epoch 056 | Test score: 0.0004 <<< BEST VALIDATION EPOCH
# Epoch 057 | Test score: 0.0005
# Epoch 058 | Test score: 0.0004
# Epoch 059 | Test score: 0.0007
# Epoch 060 | Test score: 0.0005
# Epoch 061 | Test score: 0.0003 <<< BEST VALIDATION EPOCH
# Epoch 062 | Test score: 0.0003
# Epoch 063 | Test score: 0.0003
# Epoch 064 | Test score: 0.0003 <<< BEST VALIDATION EPOCH
# Epoch 065 | Test score: 0.0004
# Epoch 066 | Test score: 0.0004
# Epoch 067 | Test score: 0.0010
# Epoch 068 | Test score: 0.0008
# Epoch 069 | Test score: 0.0005
# Epoch 070 | Test score: 0.0003
# Epoch 071 | Test score: 0.0005
# Epoch 072 | Test score: 0.0004
# Epoch 073 | Test score: 0.0004
# Epoch 074 | Test score: 0.0005
# Epoch 075 | Test score: 0.0006
# Epoch 076 | Test score: 0.0008
# Epoch 077 | Test score: 0.0006
# Epoch 078 | Test score: 0.0005
# Epoch 079 | Test score: 0.0003
# Epoch 080 | Test score: 0.0004
# Epoch 081 | Test score: 0.0003 <<< BEST VALIDATION EPOCH
# Epoch 082 | Test score: 0.0004
# Epoch 083 | Test score: 0.0005
# Epoch 084 | Test score: 0.0004
# Epoch 085 | Test score: 0.0004
# Epoch 086 | Test score: 0.0003
# Epoch 087 | Test score: 0.0003 <<< BEST VALIDATION EPOCH
# Epoch 088 | Test score: 0.0003
# Epoch 089 | Test score: 0.0005
# Epoch 090 | Test score: 0.0007
# Epoch 091 | Test score: 0.0005
# Epoch 092 | Test score: 0.0003
# Epoch 093 | Test score: 0.0004
# Epoch 094 | Test score: 0.0003
# Epoch 095 | Test score: 0.0002 <<< BEST VALIDATION EPOCH
# Epoch 096 | Test score: 0.0002 <<< BEST VALIDATION EPOCH
# Epoch 097 | Test score: 0.0003
# Epoch 098 | Test score: 0.0002
# Epoch 099 | Test score: 0.0004
# Epoch 100 | Test score: 0.0006
# Epoch 101 | Test score: 0.0006
# Epoch 102 | Test score: 0.0003
# Epoch 103 | Test score: 0.0003
# Epoch 104 | Test score: 0.0003
# Epoch 105 | Test score: 0.0003
# Epoch 106 | Test score: 0.0003
# Epoch 107 | Test score: 0.0004
# Epoch 108 | Test score: 0.0008
# Epoch 109 | Test score: 0.0004
# Epoch 110 | Test score: 0.0003
# Epoch 111 | Test score: 0.0004
# Epoch 112 | Test score: 0.0003
# Epoch 113 | Test score: 0.0007
# Epoch 114 | Test score: 0.0005
# Epoch 115 | Test score: 0.0003
# Epoch 116 | Test score: 0.0002
# Epoch 117 | Test score: 0.0003
# Epoch 118 | Test score: 0.0006
# Epoch 119 | Test score: 0.0002
# Epoch 120 | Test score: 0.0003
# Epoch 121 | Test score: 0.0003
# Epoch 122 | Test score: 0.0004
# Epoch 123 | Test score: 0.0004
# Epoch 124 | Test score: 0.0006
# Epoch 125 | Test score: 0.0007
# Epoch 126 | Test score: 0.0003
# Epoch 127 | Test score: 0.0003
# Epoch 128 | Test score: 0.0003
# Epoch 129 | Test score: 0.0002
# Epoch 130 | Test score: 0.0002 <<< BEST VALIDATION EPOCH
# Epoch 131 | Test score: 0.0004
# Epoch 132 | Test score: 0.0003
# Epoch 133 | Test score: 0.0005
# Epoch 134 | Test score: 0.0010
# Epoch 135 | Test score: 0.0002
# Epoch 136 | Test score: 0.0002
# Epoch 137 | Test score: 0.0002 <<< BEST VALIDATION EPOCH
# Epoch 138 | Test score: 0.0004
# Epoch 139 | Test score: 0.0003
# Epoch 140 | Test score: 0.0002
# Epoch 141 | Test score: 0.0007
# Epoch 142 | Test score: 0.0004
# Epoch 143 | Test score: 0.0002
# Epoch 144 | Test score: 0.0003
# Epoch 145 | Test score: 0.0003
# Epoch 146 | Test score: 0.0003
# Epoch 147 | Test score: 0.0005
# Epoch 148 | Test score: 0.0004
# Epoch 149 | Test score: 0.0004
# Epoch 150 | Test score: 0.0002
# Epoch 151 | Test score: 0.0003
# Epoch 152 | Test score: 0.0002
# Epoch 153 | Test score: 0.0003
# Epoch 154 | Test score: 0.0002
# Epoch 155 | Test score: 0.0002
# Epoch 156 | Test score: 0.0006
# Epoch 157 | Test score: 0.0004
# Epoch 158 | Test score: 0.0004
# Epoch 159 | Test score: 0.0005
# Epoch 160 | Test score: 0.0013
# Epoch 161 | Test score: 0.0006
# Epoch 162 | Test score: 0.0003
# Epoch 163 | Test score: 0.0002
# Epoch 164 | Test score: 0.0002
# Epoch 165 | Test score: 0.0005
# Epoch 166 | Test score: 0.0003
# Epoch 167 | Test score: 0.0002
# Epoch 168 | Test score: 0.0003
# Epoch 169 | Test score: 0.0002
# Epoch 170 | Test score: 0.0005
# Epoch 171 | Test score: 0.0002
# Epoch 172 | Test score: 0.0003
# Epoch 173 | Test score: 0.0003
# Epoch 174 | Test score: 0.0007
# Epoch 175 | Test score: 0.0002
# Epoch 176 | Test score: 0.0006
# Epoch 177 | Test score: 0.0004
# Epoch 178 | Test score: 0.0003
# Epoch 179 | Test score: 0.0002
# Epoch 180 | Test score: 0.0003
# Epoch 181 | Test score: 0.0003
# Epoch 182 | Test score: 0.0002
# Epoch 183 | Test score: 0.0004
# Epoch 184 | Test score: 0.0003
# Epoch 185 | Test score: 0.0003
# Epoch 186 | Test score: 0.0002
# Epoch 187 | Test score: 0.0002 <<< BEST VALIDATION EPOCH
# Epoch 188 | Test score: 0.0004
# Epoch 189 | Test score: 0.0004
# Epoch 190 | Test score: 0.0004
# Epoch 191 | Test score: 0.0003
# Epoch 192 | Test score: 0.0003
# Epoch 193 | Test score: 0.0005
# Epoch 194 | Test score: 0.0002
# Epoch 195 | Test score: 0.0007
# Epoch 196 | Test score: 0.0004
# Epoch 197 | Test score: 0.0003
# Epoch 198 | Test score: 0.0004
# Epoch 199 | Test score: 0.0002
# Epoch 200 | Test score: 0.0004
# Epoch 201 | Test score: 0.0003
# Epoch 202 | Test score: 0.0006
# Epoch 203 | Test score: 0.0004
# Epoch 204 | Test score: 0.0002
# Epoch 205 | Test score: 0.0002
# Epoch 206 | Test score: 0.0002
# Epoch 207 | Test score: 0.0008
# Epoch 208 | Test score: 0.0002
# Epoch 209 | Test score: 0.0002
# Epoch 210 | Test score: 0.0002
# Epoch 211 | Test score: 0.0004
# Epoch 212 | Test score: 0.0003
# Epoch 213 | Test score: 0.0003
# Epoch 214 | Test score: 0.0003
# Epoch 215 | Test score: 0.0003
# Epoch 216 | Test score: 0.0004
# Epoch 217 | Test score: 0.0002
# Epoch 218 | Test score: 0.0004
# Epoch 219 | Test score: 0.0006
# Epoch 220 | Test score: 0.0003
# Epoch 221 | Test score: 0.0003
# Epoch 222 | Test score: 0.0005
# Epoch 223 | Test score: 0.0002
# Epoch 224 | Test score: 0.0003
# Epoch 225 | Test score: 0.0002
# Epoch 226 | Test score: 0.0005
# Epoch 227 | Test score: 0.0005
# Epoch 228 | Test score: 0.0008
# Epoch 229 | Test score: 0.0005
# Epoch 230 | Test score: 0.0004
# Epoch 231 | Test score: 0.0002
# Epoch 232 | Test score: 0.0005
# Epoch 233 | Test score: 0.0003
# Epoch 234 | Test score: 0.0002
# Epoch 235 | Test score: 0.0002
# Epoch 236 | Test score: 0.0002
# Epoch 237 | Test score: 0.0003
# Epoch 238 | Test score: 0.0003
# Epoch 239 | Test score: 0.0003
# Epoch 240 | Test score: 0.0004
# Epoch 241 | Test score: 0.0003
# Epoch 242 | Test score: 0.0004
# Epoch 243 | Test score: 0.0003
# Epoch 244 | Test score: 0.0003
# Epoch 245 | Test score: 0.0003
# Epoch 246 | Test score: 0.0004
# Epoch 247 | Test score: 0.0004
# Epoch 248 | Test score: 0.0002
# Epoch 249 | Test score: 0.0003
# Epoch 250 | Test score: 0.0002
# Epoch 251 | Test score: 0.0002
# Epoch 252 | Test score: 0.0003
# Epoch 253 | Test score: 0.0004
# Epoch 254 | Test score: 0.0005
# Epoch 255 | Test score: 0.0003
# Epoch 256 | Test score: 0.0002
# Epoch 257 | Test score: 0.0005
# Epoch 258 | Test score: 0.0002
# Epoch 259 | Test score: 0.0002
# Epoch 260 | Test score: 0.0002
# Epoch 261 | Test score: 0.0002
# Epoch 262 | Test score: 0.0006
# Epoch 263 | Test score: 0.0004
# Epoch 264 | Test score: 0.0002
# Epoch 265 | Test score: 0.0002
# Epoch 266 | Test score: 0.0002
# Epoch 267 | Test score: 0.0002
# Epoch 268 | Test score: 0.0006
# Epoch 269 | Test score: 0.0003
# Epoch 270 | Test score: 0.0004
# Epoch 271 | Test score: 0.0010
# Epoch 272 | Test score: 0.0002
# Epoch 273 | Test score: 0.0003
# Epoch 274 | Test score: 0.0002
# Epoch 275 | Test score: 0.0003
# Epoch 276 | Test score: 0.0003
# Epoch 277 | Test score: 0.0004
# Epoch 278 | Test score: 0.0003
# Epoch 279 | Test score: 0.0006
# Epoch 280 | Test score: 0.0003
# Epoch 281 | Test score: 0.0003
# Epoch 282 | Test score: 0.0007
# Epoch 283 | Test score: 0.0004
# Epoch 284 | Test score: 0.0005
# Epoch 285 | Test score: 0.0003
# Epoch 286 | Test score: 0.0003
# Epoch 287 | Test score: 0.0003
# Epoch 288 | Test score: 0.0005

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,6))
plt.plot(losses['inp_2222'], label='inp_2222')
plt.plot(losses['inp_3334'], label='inp_3334')
plt.plot(losses['full_data'], label='full_data')
plt.xlabel('number of epochs')
plt.ylabel('rmse loss')
plt.legend()
plt.grid()
plt.show()
